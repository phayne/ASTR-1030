# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
image_file = '/Users/paha3326/main/Teaching/ASTR1030/hayne/lab/night/saturn-data/Saturn_AE_NM_CB_18Sep.fit'

# %%
hdu_list = fits.open(image_file)
hdu_list.info()
# Out:
# Filename: /Users/paha3326/main/Teaching/ASTR1030/hayne/lab/night/saturn-data/Saturn_AE_NM_CB_18Sep.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      51   (3352, 2532)   int16 (rescales to uint16)

# %%
image_data = hdu_list[0].data

# %%
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (2532, 3352)

# %%
hdu_list.close()

# %%
image_data = fits.getdata(image_file)
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (2532, 3352)

# %%
plt.figure(figsize=[20,15])
plt.subplot(131)
plt.imshow(image_data, cmap='gray', vmin=1000, vmax=2500)
plt.subplot(132)
plt.imshow(image_data, cmap='gray', vmin=800, vmax=1600)
plt.subplot(133)
plt.imshow(image_data, cmap='gray', vmin=600, vmax=1300)
#plt.colorbar()
#plt.axis([0,2500,0,2500])
# To see more color maps
# http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps
